# %%
z = var ('z')
f ( z ) = z ^4 - 2* z ^3 + 2* z ^2 - 2* z + 1
complex_plot (f ,( -2 ,2) , ( -2 ,2) )
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# En particulier, les points noirs correspondent aux zéros de la fonction. Ici, on a deux zéros imaginaires
# et un zéro réel. *Lesquels ?* On peut déterminer la multiplicité d’un zéro en regardant le comportement de
# f (z) alentours.
#
# On peux voir les 2 zero imaginaire en i et -i et le zero reel en 1

# %% [markdown]
# exo 1
# f (z) = z^2 − z − 1
# g(z) =(1/z) + z
# h(z) = cos z

# %%
z = var ('z')
def plotComplex(f, im = ( -2 ,2), re = ( -2 ,2)):
    show(complex_plot(f, im, re))

# %%
f(z) = z^2 - z - 1
plotComplex(f)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# On remarque ici deux zero reel dont leur racine sont simple

# %%
g(z) = 1/z + z
plotComplex(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# On remarque ici deux zero imaginaire dont leur racine sont simple

# %%
h(z) = cos(z)
plotComplex(h)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# On remarque ici deux zero reel dont leur racine sont simple

# %%
EXO 2
# Out:
#   Input In [33]
#     EXO Integer(2)
#         ^
# SyntaxError: invalid syntax

# %%
n = var('n')
f(n) = ((-1)^n/3^(n+1)) * (z - 3)^n
s(z) = f(0) + f(1) + f(2) + f(3)
show(s)
plotComplex(s, (-2, 10))
# Out:
# z |--> -1/81*(z - 3)^3 + 1/27*(z - 3)^2 - 1/9*z + 2/3
# Graphics object consisting of 1 graphics primitive
